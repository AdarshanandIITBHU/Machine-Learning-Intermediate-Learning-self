# %% [markdown]
# <a href="https://colab.research.google.com/github/AdarshanandIITBHU/Machine-Learning-Intermediate-Learning-self/blob/main/Tensors.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
from google.colab import files
from IPython.display import Image, display

def add_image():
    uploaded = files.upload()
    for fname in uploaded.keys():
        display(Image(fname))

# %%
a=np.array(4)

# %%
a
a.ndim
# Out:
# 0

# %%
arr=np.array([1,2,3])
print(arr)
# Out:
# [1 2 3]

# %%
arr.ndim
# Out:
# 1

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# 2-d tensor

# %%
arr1=np.array([[1,2,3],[2,5,6],[1,6,9]])
arr1.ndim
# Out:
# 2

# %% [markdown]
# 3-d tensor

# %%
arr2=np.array([[[1,2],[2,3]],[[2,4],[3,4]],[[1,9],[9,8]]])
arr2.shape
# Out:
# (3, 2, 2)

# %%
add_image()
# Out:
#      <input type="file" id="files-f20e9d06-1ebe-407c-8d85-d24772fe7ff2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f20e9d06-1ebe-407c-8d85-d24772fe7ff2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
add_image()
# Out:
#      <input type="file" id="files-e5dc9746-8437-4bbb-a343-9596c57e987b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e5dc9746-8437-4bbb-a343-9596c57e987b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df=pd.read_csv('/content/drive/My Drive/Colab Notebooks/datasets/air_quality.csv')
df
# Out:
#       Date  Month  Year  Holidays_Count  Days   PM2.5    PM10     NO2    SO2  \
# 0        1      1  2021               0     5  408.80  442.42  160.61  12.95
# 1        2      1  2021               0     6  404.04  561.95   52.85   5.18
# 2        3      1  2021               1     7  225.07  239.04  170.95  10.93
# 3        4      1  2021               0     1   89.55  132.08  153.98  10.42
# 4        5      1  2021               0     2   54.06   55.54  122.66   9.70
# ...    ...    ...   ...             ...   ...     ...     ...     ...    ...
# 1456    27     12  2024               0     5   58.43  249.17   41.69  65.89
# 1457    28     12  2024               0     6   33.83  150.77   33.31  66.14
# 1458    29     12  2024               1     7   31.21  139.75   27.01  65.94
# 1459    30     12  2024               0     1   38.01  152.83   29.12  65.16
# 1460    31     12  2024               0     2   80.42  318.96   40.37  64.98
#
#         CO  Ozone  AQI
# ...
